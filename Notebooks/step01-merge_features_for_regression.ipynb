# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # LOF/GOF calls

# %%
gof = pd.read_csv('./Data/GOF_matrix_808cells_18111genes_Avana20q4.csv', index_col=0, dtype=object)
lof = pd.read_csv('./Data/LOF_matrix_808cells_18111genes_Avana20q4.csv', index_col=0, dtype=object)
gof = gof.T
lof = lof.T
print(gof.info())
print(lof.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 808 entries, ACH-001172 to ACH-002510
# Columns: 18111 entries, A1BG to ZZZ3
# dtypes: object(18111)
# memory usage: 111.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 808 entries, ACH-001172 to ACH-002510
# Columns: 18111 entries, A1BG to ZZZ3
# dtypes: object(18111)
# memory usage: 111.7+ MB
# None

# %%
gof.replace('GOF',1, inplace=True)
gof.fillna(0, inplace=True)
gof = gof.astype(bool)
gof.head()
# Out:
#              A1BG   A1CF    A2M  A2ML1  A3GALT2  A4GALT  A4GNT   AAAS   AACS  \
# ACH-001172  False  False  False  False    False   False  False  False  False
# ACH-002017  False  False  False  False    False   False  False  False  False
# ACH-001145  False  False  False  False    False   False  False  False  False
# ACH-000995  False  False  False  False    False   False  False  False  False
# ACH-000391  False  False  False  False    False   False  False  False  False
#
#             AADAC  ...  ZWILCH  ZWINT   ZXDA   ZXDB   ZXDC  ZYG11A  ZYG11B  \
# ACH-001172  False  ...   False  False  False  False  False   False   False
# ACH-002017  False  ...   False  False  False  False  False   False   False
# ACH-001145  False  ...   False  False  False  False  False   False   False
# ACH-000995  False  ...   False  False  False  False  False   False   False
# ACH-000391  False  ...   False  False  False  False  False   False   False
#
#               ZYX  ZZEF1   ZZZ3
# ACH-001172  False  False  False
# ACH-002017  False  False  False
# ACH-001145  False  False  False
# ACH-000995  False  False  False
# ACH-000391  False  False  False
#
# [5 rows x 18111 columns]

# %%
lof.replace('LOF',1, inplace=True)
lof.fillna(0, inplace=True)
lof = lof.astype(bool)
lof.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 808 entries, ACH-001172 to ACH-002510
# Columns: 18111 entries, A1BG to ZZZ3
# dtypes: bool(18111)
# memory usage: 14.0+ MB

# %% [markdown]
# # EMT from gene expression

# %%
expr = pd.read_csv('./Data/CCLE_expression_718cellsInAvana20q4_17893genes.txt', index_col=0, sep='\t')
expr = expr.T
expr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 718 entries, ACH-001001 to ACH-000097
# Columns: 17893 entries, TSPAN6 to ZBTB8B
# dtypes: float64(17893)
# memory usage: 98.0+ MB

# %%
emt = pd.DataFrame( index=expr.index, columns=['cdh1_vim_ratio'], data=0)
emt.cdh1_vim_ratio = expr.CDH1 - expr.VIM
emt.head()
# Out:
#             cdh1_vim_ratio
# ACH-001001          -10.29
# ACH-000948            5.49
# ACH-000011           -5.92
# ACH-000323          -12.16
# ACH-000905           -3.43

# %%
emt.cdh1_vim_ratio.hist( bins=arange(-15,10))
# Out:
# <AxesSubplot:>

# %%
emt['CDH_VIM_hi'] = 0
emt['CDH_VIM_lo'] = 0
emt.loc[ emt.index[ where( emt.cdh1_vim_ratio>1)[0] ] , 'CDH_VIM_hi'] = 1 
emt.loc[ emt.index[ where( emt.cdh1_vim_ratio<-4)[0] ] , 'CDH_VIM_lo'] = 1

# %%
emt.head()
# Out:
#             cdh1_vim_ratio  CDH_VIM_hi  CDH_VIM_lo
# ACH-001001          -10.29           0           1
# ACH-000948            5.49           1           0
# ACH-000011           -5.92           0           1
# ACH-000323          -12.16           0           1
# ACH-000905           -3.43           0           0

# %%
emt.drop('cdh1_vim_ratio', axis=1, inplace=True)

# %% [markdown]
# # Cell line metadata

# %%
cells = pd.read_csv('./Data/sample_info_808cells_20q4Avana.csv', index_col=0)
cells.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 808 entries, ACH-001172 to ACH-002510
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   cell_line_name             792 non-null    object
#  1   stripped_cell_line_name    808 non-null    object
#  2   CCLE_Name                  808 non-null    object
#  3   alias                      36 non-null     object
#  4   COSMICID                   416 non-null    float64
#  5   sex                        808 non-null    object
#  6   source                     808 non-null    object
#  7   Achilles_n_replicates      808 non-null    float64
#  8   cell_line_NNMD             808 non-null    float64
#  9   culture_type               643 non-null    object
#  10  culture_medium             808 non-null    object
#  11  cas9_activity              799 non-null    float64
#  12  RRID                       750 non-null    object
#  13  WTSI_Master_Cell_ID        416 non-null    float64
#  14  sample_collection_site     808 non-null    object
#  15  primary_or_metastasis      621 non-null    object
#  16  primary_disease            808 non-null    object
#  17  Subtype                    777 non-null    object
#  18  age                        544 non-null    float64
#  19  Sanger_Model_ID            491 non-null    object
#  20  depmap_public_comments     5 non-null      object
#  21  lineage                    808 non-null    object
#  22  lineage_subtype            803 non-null    object
#  23  lineage_sub_subtype        405 non-null    object
#  24  lineage_molecular_subtype  77 non-null     object
# dtypes: float64(6), object(19)
# memory usage: 164.1+ KB

# %%
cells = cells[ ['cell_line_name', 'stripped_cell_line_name', 'CCLE_Name', 'sex', 
       'culture_type', 'culture_medium', 'primary_disease', 'Subtype', 'age',
       'lineage', 'lineage_subtype', 'lineage_sub_subtype', 'lineage_molecular_subtype']]

# %% [markdown]
# ### Add MSI from Chan et al

# %%
chan = pd.read_excel('./Data/Chan_et_al_2019_Supplementary_Table_1.xlsx')
chan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1415 entries, 0 to 1414
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CCLE_ID                       1415 non-null   object
#  1   Lineage                       1183 non-null   object
#  2   GDSC_MSI                      985 non-null    object
#  3   CCLE_MSI                      1330 non-null   object
#  4   DRIVE_WRN_D2                  383 non-null    float64
#  5   CRISPR_WRN_CERES              517 non-null    float64
#  6   avg_WRN_dep                   680 non-null    float64
#  7   is_WRN_dep                    680 non-null    float64
#  8   TP53_status                   921 non-null    object
#  9   common_MSI_lineage            1415 non-null   bool
#  10  ms_deletions_normed           1330 non-null   float64
#  11  frac_deletions_in_ms_regions  1330 non-null   float64
#  12  MMR_loss                      969 non-null    float64
#  13  MMR_loss_gene                 943 non-null    object
#  14  MLH1_damaging_mut             1323 non-null   float64
#  15  MLH1_unexpressed              969 non-null    float64
#  16  MLH1_deletion                 984 non-null    float64
#  17  MLH1_loss                     951 non-null    float64
#  18  MSH2_damaging_mut             1323 non-null   float64
#  19  MSH2_unexpressed              969 non-null    float64
#  20  MSH2_deletion                 984 non-null    float64
#  21  MSH2_loss                     951 non-null    float64
#  22  MSH6_damaging_mut             1323 non-null   float64
#  23  MSH6_unexpressed              969 non-null    float64
#  24  MSH6_deletion                 984 non-null    float64
#  25  MSH6_loss                     950 non-null    float64
#  26  PMS2_damaging_mut             1323 non-null   float64
#  27  PMS2_unexpressed              969 non-null    float64
#  28  PMS2_deletion                 984 non-null    float64
#  29  PMS2_loss                     949 non-null    float64
#  30  MSH2_RPPA_low                 892 non-null    float64
#  31  MSH6_RPPA_low                 892 non-null    float64
#  32  any_MMR_mut                   1323 non-null   float64
#  33  POLE_damaging_mut             1323 non-null   float64
#  34  POLE_hotspot_mut              1320 non-null   float64
#  35  POLE_other_mut                1323 non-null   float64
#  36  Comments                      2 non-null      object
# dtypes: bool(1), float64(29), object(7)
# memory usage: 399.5+ KB

# %%
msi_dict = chan.set_index('CCLE_ID')['CCLE_MSI'].to_dict()
cells['MSI'] = cells['CCLE_Name'].map(msi_dict )
cells.groupby('MSI')['MSI'].count()
# Out:
# MSI
# MSI               45
# MSS              538
# indeterminate      3
# Name: MSI, dtype: int64

# %%
cells.head(5)
# Out:
#            cell_line_name stripped_cell_line_name  \
# DepMap_ID
# ACH-001172            NaN                    R256
# ACH-002017           Omm1                    OMM1
# ACH-001145         OC 316                   OC316
# ACH-000995         JURKAT                  JURKAT
# ACH-000391       MHH-ES-1                  MHHES1
#
#                                             CCLE_Name      sex culture_type  \
# DepMap_ID
# ACH-001172                R256_CENTRAL_NERVOUS_SYSTEM  Unknown    not found
# ACH-002017                                  OMM1_UVEA     Male     Adherent
# ACH-001145                                OC316_OVARY   Female     Adherent
# ACH-000995  JURKAT_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     Male   Suspension
# ACH-000391                                MHHES1_BONE     Male     Adherent
#
#                                      culture_medium primary_disease  \
# DepMap_ID
# ACH-001172                                not found    Brain Cancer
# ACH-002017  RPMI 1640 + 20% FBS (w/3mM L-glutamine)      Eye Cancer
# ACH-001145                       RPMI 1640 + 5% FBS  Ovarian Cancer
# ACH-000995                       RPMI-1640 +10% FBS        Leukemia
# ACH-000391                           RPMI + 10% FBS     Bone Cancer
#
#                                                Subtype   age  \
# DepMap_ID
# ACH-001172                             Medulloblastoma   NaN
# ACH-002017                              Uveal Melanoma   NaN
# ACH-001145                      Adenocarcinoma, serous  60.0
# ACH-000995  Acute Lymphoblastic Leukemia (ALL), T-cell   NaN
# ACH-000391                              Ewings Sarcoma  12.0
#
#                            lineage       lineage_subtype lineage_sub_subtype  \
# DepMap_ID
# ACH-001172  central_nervous_system       medulloblastoma                 NaN
# ACH-002017                     eye        uveal_melanoma                 NaN
# ACH-001145                   ovary  ovary_adenocarcinoma              serous
# ACH-000995                   blood                   ALL              t_cell
# ACH-000391                    bone         Ewing_sarcoma                 NaN
#
#            lineage_molecular_subtype  MSI
# DepMap_ID
# ACH-001172                       NaN  NaN
# ACH-002017                       NaN  NaN
# ACH-001145                       NaN  MSI
# ACH-000995                       NaN  MSI
# ACH-000391                   EWS_FLI  MSS

# %%
cells.groupby('MSI').MSI.count()
# Out:
# MSI
# MSI               45
# MSS              538
# indeterminate      3
# Name: MSI, dtype: int64

# %%
cells.groupby('lineage_subtype').count()
# Out:
#                               cell_line_name  stripped_cell_line_name  \
# lineage_subtype
# ALL                                       13                       13
# AML                                       23                       23
# ATL                                        0                        1
# ATRT                                       5                        5
# CLL                                        1                        1
# ...                                      ...                      ...
# undifferentiated_sarcoma                   1                        1
# unspecified_leukemia                       3                        3
# upper_aerodigestive_squamous              32                       33
# uterine_carcinosarcoma                     1                        1
# uveal_melanoma                             5                        5
#
#                               CCLE_Name  sex  culture_type  culture_medium  \
# lineage_subtype
# ALL                                  13   13            10              13
# AML                                  23   23            16              23
# ATL                                   1    1             1               1
# ATRT                                  5    5             5               5
# CLL                                   1    1             1               1
# ...                                 ...  ...           ...             ...
# undifferentiated_sarcoma              1    1             1               1
# unspecified_leukemia                  3    3             3               3
# upper_aerodigestive_squamous         33   33            22              33
# uterine_carcinosarcoma                1    1             1               1
# uveal_melanoma                        5    5             5               5
#
#                               primary_disease  Subtype  age  lineage  \
# lineage_subtype
# ALL                                        13       13   10       13
# AML                                        23       23   22       23
# ATL                                         1        1    0        1
# ATRT                                        5        5    4        5
# CLL                                         1        1    1        1
# ...                                       ...      ...  ...      ...
# undifferentiated_sarcoma                    1        1    0        1
# unspecified_leukemia                        3        3    3        3
# upper_aerodigestive_squamous               33       33   24       33
# uterine_carcinosarcoma                      1        1    1        1
# uveal_melanoma                              5        5    2        5
#
#                               lineage_sub_subtype  lineage_molecular_subtype  \
# lineage_subtype
# ALL                                            13                          0
# AML                                            14                          0
# ATL                                             0                          0
# ATRT                                            0                          0
# CLL                                             1                          0
# ...                                           ...                        ...
# undifferentiated_sarcoma                        0                          0
# unspecified_leukemia                            3                          0
# upper_aerodigestive_squamous                   25                          0
# uterine_carcinosarcoma                          0                          0
# uveal_melanoma                                  0                          0
#
#                               MSI
# lineage_subtype
# ALL                             9
# AML                            19
# ATL                             0
# ATRT                            0
# CLL                             1
# ...                           ...
# undifferentiated_sarcoma        0
# unspecified_leukemia            0
# upper_aerodigestive_squamous   28
# uterine_carcinosarcoma          0
# uveal_melanoma                  0
#
# [76 rows x 13 columns]

# %%
cell_meta_binary = pd.DataFrame( index=cells.index, dtype=bool )

#
# lineage
#
types = list(set(cells.lineage ) )
types = [str(x) for x in types]
types = [x for x in types if x != 'nan']
for header in types:
    cell_meta_binary[header] = False
    for ach in cell_meta_binary.index.values:
        if ( cells.loc[ach]['lineage']==header ):
            cell_meta_binary.loc[ach, header]=True
            
#
# lineage subtype
#
types = list(set(cells.lineage_subtype ) )
types = [str(x) for x in types]
types = [x for x in types if x != 'nan']
for header in types:
    cell_meta_binary[header] = False
    for ach in cell_meta_binary.index.values:
        if ( cells.loc[ach]['lineage_subtype']==header ):
            cell_meta_binary.loc[ach, header]=True

#
# lineage sub_subtype
#
types = list(set(cells.lineage_sub_subtype ) )
types = [str(x) for x in types]
types = [x for x in types if x != 'nan']
for header in types:
    cell_meta_binary[header] = False
    for ach in cell_meta_binary.index.values:
        if ( cells.loc[ach]['lineage_sub_subtype']==header ):
            cell_meta_binary.loc[ach, header]=True

#
# culture_type
#
types = list(set(cells.culture_type ) )
types = [str(x) for x in types]
types = [x for x in types if x != 'nan']
for header in types:
    cell_meta_binary[header] = False
    for ach in cell_meta_binary.index.values:
        if ( cells.loc[ach]['culture_type']==header ):
            cell_meta_binary.loc[ach, header]=True

#
# sex
#
types = list(set(cells.sex ) )
types = [str(x) for x in types]
types = [x for x in types if x != 'nan']
for header in types:
    cell_meta_binary[header] = False
    for ach in cell_meta_binary.index.values:
        if ( cells.loc[ach]['sex']==header ):
            cell_meta_binary.loc[ach, header]=True
            
#
# MSI
#
types = list(set(cells.MSI ) )
types = [str(x) for x in types]
types = [x for x in types if x != 'nan']
for header in types:
    cell_meta_binary[header] = False
    for ach in cell_meta_binary.index.values:
        if ( cells.loc[ach]['MSI']==header ):
            cell_meta_binary.loc[ach, header]=True

# %%
cell_meta_binary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 808 entries, ACH-001172 to ACH-002510
# Columns: 183 entries, plasma_cell to MSS
# dtypes: bool(183)
# memory usage: 183.0+ KB

# %%
cell_meta_binary.drop('Unknown', axis=1, inplace=True)

# %%
cell_meta_binary.sum()
# Out:
# plasma_cell       21
# ovary             43
# gastric           26
# skin              56
# embryo             1
#                 ...
# Male             402
# Female           318
# indeterminate      3
# MSI               45
# MSS              538
# Length: 182, dtype: int64

# %%
cell_meta_binary.sum()
# Out:
# plasma_cell       21
# ovary             43
# gastric           26
# skin              56
# embryo             1
#                 ...
# Male             402
# Female           318
# indeterminate      3
# MSI               45
# MSS              538
# Length: 182, dtype: int64

# %% [markdown]
# # Merge features

# %%
feats = cell_meta_binary.join( gof, how='inner')
feats = feats.join( lof, how='inner', lsuffix='_GOF', rsuffix='_LOF')
feats = feats.join( emt, how='left')
feats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 808 entries, ACH-001172 to ACH-002510
# Columns: 36406 entries, plasma_cell to CDH_VIM_lo
# dtypes: bool(36404), float64(2)
# memory usage: 28.1+ MB

# %%
num_cells_per_feat = feats.sum()

# %%
num_cells_per_feat.hist( bins=arange(10))
# Out:
# <AxesSubplot:>

# %%
#
# 2% of 808 cell lines is 16.16. filter here?
#
# CML=7. arbitrary cutoff

len( where( num_cells_per_feat <= 6)[0] )
# Out:
# 33475

# %%
too_low = where( num_cells_per_feat<=6)[0]
feats.drop( feats.columns[too_low], axis=1, inplace=True)
feats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 808 entries, ACH-001172 to ACH-002510
# Columns: 2931 entries, plasma_cell to CDH_VIM_lo
# dtypes: bool(2929), float64(2)
# memory usage: 2.3+ MB

# %%
feats.head(3)
# Out:
#             plasma_cell  ovary  gastric   skin  central_nervous_system   bone  \
# ACH-001172        False  False    False  False                    True  False
# ACH-002017        False  False    False  False                   False  False
# ACH-001145        False   True    False  False                   False  False
#
#             uterus  kidney  bile_duct  breast  ...  ZRANB3_LOF  ZSCAN29_LOF  \
# ACH-001172   False   False      False   False  ...       False        False
# ACH-002017   False   False      False   False  ...       False        False
# ACH-001145   False   False      False   False  ...       False        False
#
#             ZSWIM5_LOF  ZSWIM6_LOF  ZSWIM8_LOF  ZWILCH_LOF  ZXDC_LOF  \
# ACH-001172       False       False       False       False     False
# ACH-002017       False       False       False       False     False
# ACH-001145        True        True       False       False     False
#
#             ZZEF1_LOF  CDH_VIM_hi  CDH_VIM_lo
# ACH-001172      False         NaN         NaN
# ACH-002017      False         NaN         NaN
# ACH-001145      False         0.0         1.0
#
# [3 rows x 2931 columns]

# %%
feats = feats.astype(bool)

# %%
feats.head(3)
# Out:
#             plasma_cell  ovary  gastric   skin  central_nervous_system   bone  \
# ACH-001172        False  False    False  False                    True  False
# ACH-002017        False  False    False  False                   False  False
# ACH-001145        False   True    False  False                   False  False
#
#             uterus  kidney  bile_duct  breast  ...  ZRANB3_LOF  ZSCAN29_LOF  \
# ACH-001172   False   False      False   False  ...       False        False
# ACH-002017   False   False      False   False  ...       False        False
# ACH-001145   False   False      False   False  ...       False        False
#
#             ZSWIM5_LOF  ZSWIM6_LOF  ZSWIM8_LOF  ZWILCH_LOF  ZXDC_LOF  \
# ACH-001172       False       False       False       False     False
# ACH-002017       False       False       False       False     False
# ACH-001145        True        True       False       False     False
#
#             ZZEF1_LOF  CDH_VIM_hi  CDH_VIM_lo
# ACH-001172      False        True        True
# ACH-002017      False        True        True
# ACH-001145      False       False        True
#
# [3 rows x 2931 columns]

# %%
features = feats.columns.values
numGof = len( [x for x in features if '_GOF' in x])
numLof = len( [x for x in features if '_LOF' in x])
print(numGof, numLof)
# Out:
# 91 2763

# %%
numCells, numFeats = feats.shape
print(numFeats, numCells)
# Out:
# 2931 808

# %%
feats.to_csv('./Data/binFeats-cells-metadata-lof-gof-emt-' + str(numFeats) + 'feats-' + str(numCells) + 'cells-Avana20q4.txt', sep='\t', index=True)
