# %%
# %pylab inline
import pandas as pd
import scipy.stats as stats
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
rcParams['pdf.fonttype']=42
rcParams['font.family']='sans-serif'
rcParams['font.size']=10

# %%
def qnorm_dataframe( data ):
    """
    quantile normalize a dataframe with numeric values only!
    """
    rank_mean = data.stack().groupby(data.rank(method='first').stack().astype(int)).mean()
    qnormed_data    = data.rank(method='min').stack().astype(int).map(rank_mean).unstack()
    return qnormed_data

# %%
drugsens = pd.read_csv('/Data/HartLab/Drug_sensitivity/primary_replicate_collapsed_logfold_change.csv',
                        index_col=0)
drugsens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 578 entries, ACH-000001 to ACH-001321
# Columns: 4686 entries, BRD-A00077618-236-07-6::2.5::HTS to BRD-M63173034-001-03-6::2.64076472::MTS004
# dtypes: float64(4686)
# memory usage: 20.7+ MB

# %%
druginfo = pd.read_csv('/Data/HartLab/Drug_sensitivity/primary_replicate_collapsed_treatment_info.csv',
                      index_col=0)
druginfo.fillna('-', inplace=True)
druginfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4686 entries, BRD-A00055058-001-01-0::2.325889319::MTS004 to BRD-U51753822-000-01-1::2.5::HTS
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   broad_id      4686 non-null   object
#  1   name          4685 non-null   object
#  2   dose          4686 non-null   float64
#  3   screen_id     4686 non-null   object
#  4   moa           4325 non-null   object
#  5   target        3464 non-null   object
#  6   disease.area  1916 non-null   object
#  7   indication    1916 non-null   object
#  8   smiles        4684 non-null   object
#  9   phase         4685 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 402.7+ KB

# %%
drugsens.head()
# Out:
#             BRD-A00077618-236-07-6::2.5::HTS  \
# ACH-000001                         -0.015577
# ACH-000007                         -0.095730
# ACH-000008                          0.379480
# ACH-000010                          0.118890
# ACH-000011                          0.145346
#
#             BRD-A00100033-001-08-9::2.5::HTS  \
# ACH-000001                         -0.449332
# ACH-000007                          0.257943
# ACH-000008                         -0.596132
# ACH-000010                         -0.231615
# ACH-000011                         -0.499274
#
#             BRD-A00147595-001-01-5::2.5::HTS  \
# ACH-000001                          0.489379
# ACH-000007                          0.772349
# ACH-000008                          0.548056
# ACH-000010                          0.621937
# ACH-000011                          0.267470
#
#             BRD-A00218260-001-03-4::2.5::HTS  \
# ACH-000001                          0.206675
# ACH-000007                         -0.438502
# ACH-000008                          0.422269
# ACH-000010                         -0.202707
# ACH-000011                          0.157804
#
#             BRD-A00376169-001-01-6::2.5::HTS  \
# ACH-000001                          0.272730
# ACH-000007                         -0.732832
# ACH-000008                         -0.216986
# ACH-000010                         -1.005139
# ACH-000011                         -0.272286
#
#             BRD-A00520476-001-07-4::2.5::HTS  \
# ACH-000001                          0.021036
# ACH-000007                          0.779201
# ACH-000008                          0.081866
# ACH-000010                         -0.213739
# ACH-000011                          0.207768
#
#             BRD-A00546892-001-02-6::2.5::HTS  \
# ACH-000001                         -0.025460
# ACH-000007                          0.426523
# ACH-000008                          0.145335
# ACH-000010                          0.020246
# ACH-000011                          0.004464
#
#             BRD-A00578795-001-04-3::2.5::HTS  \
# ACH-000001                          0.467158
# ACH-000007                         -1.288508
# ACH-000008                         -0.570841
# ACH-000010                         -0.795278
# ACH-000011                         -0.191680
#
#             BRD-A00758722-001-04-9::2.5::HTS  \
# ACH-000001                         -0.736306
# ACH-000007                         -0.476133
# ACH-000008                         -0.512119
# ACH-000010                               NaN
# ACH-000011                         -0.310375
#
#             BRD-A00827783-001-24-6::2.5::HTS  ...  \
# ACH-000001                          0.644137  ...
# ACH-000007                         -0.277105  ...
# ACH-000008                          0.452698  ...
# ACH-000010                          0.679571  ...
# ACH-000011                          0.112537  ...
#
#             BRD-K98557884-001-01-6::2.5::MTS004  \
# ACH-000001                             0.429238
# ACH-000007                            -0.471486
# ACH-000008                            -0.111951
# ACH-000010                             0.200605
# ACH-000011                            -0.076863
#
#             BRD-K99077012-001-01-9::2.332734192::MTS004  \
# ACH-000001                                     0.204841
# ACH-000007                                     0.212998
# ACH-000008                                     0.534787
# ACH-000010                                    -0.075356
# ACH-000011                                     0.026002
#
#             BRD-K99199077-001-16-1::2.603211317::MTS004  \
# ACH-000001                                     0.150055
# ACH-000007                                    -0.123230
# ACH-000008                                     0.206642
# ACH-000010                                     0.610310
# ACH-000011                                     0.139921
#
#             BRD-K99431849-001-01-7::2.500018158::MTS004  \
# ACH-000001                                    -0.575404
# ACH-000007                                     0.625527
# ACH-000008                                    -0.410153
# ACH-000010                                    -0.019413
# ACH-000011                                    -0.261704
#
#             BRD-K99447003-335-04-1::2.37737659::MTS004  \
# ACH-000001                                   -0.101247
# ACH-000007                                    0.383198
# ACH-000008                                   -0.560722
# ACH-000010                                   -0.202971
# ACH-000011                                    0.085339
#
#             BRD-K99506538-001-03-8::2.5::MTS004  \
# ACH-000001                             0.399233
# ACH-000007                             0.212031
# ACH-000008                            -0.036088
# ACH-000010                             0.218158
# ACH-000011                             0.447482
#
#             BRD-K99616396-001-05-1::2.499991421::MTS004  \
# ACH-000001                                    -0.127658
# ACH-000007                                     0.349225
# ACH-000008                                     0.158071
# ACH-000010                                    -0.411009
# ACH-000011                                     0.164620
#
#             BRD-K99879819-001-02-1::2.5187366::MTS004  \
# ACH-000001                                  -0.141651
# ACH-000007                                  -0.387439
# ACH-000008                                   0.171043
# ACH-000010                                  -0.181540
# ACH-000011                                  -0.565251
#
#             BRD-K99919177-001-01-3::2.5::MTS004  \
# ACH-000001                            -1.153652
# ACH-000007                            -0.831461
# ACH-000008                            -3.947090
# ACH-000010                            -3.010225
# ACH-000011                            -4.110627
#
#             BRD-M63173034-001-03-6::2.64076472::MTS004
# ACH-000001                                    0.510464
# ACH-000007                                    0.323558
# ACH-000008                                    0.099310
# ACH-000010                                    0.090652
# ACH-000011                                    0.222394
#
# [5 rows x 4686 columns]

# %%
bf = pd.read_table('./Data/table_Avana2020Q4_CRISPRcleanR_corrected_all', index_col=0)
qbf = qnorm_dataframe( bf ).T
qbf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 808 entries, ACH-001172 to ACH-002510
# Columns: 18095 entries, A1BG to ZZZ3
# dtypes: float64(18095)
# memory usage: 111.6+ MB

# %%
feats = pd.read_table('./Data/features-bool-deDuped-2918feats-808cells.txt', index_col=0)
feats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 808 entries, ACH-001172 to ACH-002510
# Columns: 2918 entries, plasma_cell to CDH_VIM_lo
# dtypes: bool(2918)
# memory usage: 2.3+ MB

# %%
cell_lines_in_gdsc_and_avana = [x for x in qbf.index.values if x in drugsens.index.values]
len(cell_lines_in_gdsc_and_avana)
# Out:
# 408

# %%
drugsens = drugsens.loc[cell_lines_in_gdsc_and_avana]
qbf = qbf.loc[cell_lines_in_gdsc_and_avana]
feats = feats.loc[cell_lines_in_gdsc_and_avana]

# %%
druginfo.head()
# Out:
#                                                            broad_id  \
# column_name
# BRD-A00055058-001-01-0::2.325889319::MTS004  BRD-A00055058-001-01-0
# BRD-A00842753-001-01-9::2.5::MTS004          BRD-A00842753-001-01-9
# BRD-A02232681-001-01-8::2.5::MTS004          BRD-A02232681-001-01-8
# BRD-A04447196-001-01-8::2.5::MTS004          BRD-A04447196-001-01-8
# BRD-A04971881-003-01-3::2.65294603::MTS004   BRD-A04971881-003-01-3
#
#                                                    name      dose screen_id  \
# column_name
# BRD-A00055058-001-01-0::2.325889319::MTS004     RS-0481  2.325889    MTS004
# BRD-A00842753-001-01-9::2.5::MTS004          oleuropein  2.500000    MTS004
# BRD-A02232681-001-01-8::2.5::MTS004          isoleucine  2.500000    MTS004
# BRD-A04447196-001-01-8::2.5::MTS004           gepefrine  2.500000    MTS004
# BRD-A04971881-003-01-3::2.65294603::MTS004   cloranolol  2.652946    MTS004
#
#                                                                         moa  \
# column_name
# BRD-A00055058-001-01-0::2.325889319::MTS004                 immunostimulant
# BRD-A00842753-001-01-9::2.5::MTS004               estrogen receptor agonist
# BRD-A02232681-001-01-8::2.5::MTS004                                       -
# BRD-A04447196-001-01-8::2.5::MTS004             adrenergic receptor agonist
# BRD-A04971881-003-01-3::2.65294603::MTS004   adrenergic receptor antagonist
#
#                                                                         target  \
# column_name
# BRD-A00055058-001-01-0::2.325889319::MTS004                                  -
# BRD-A00842753-001-01-9::2.5::MTS004                                      GPER1
# BRD-A02232681-001-01-8::2.5::MTS004          ACADSB, BCAT1, BCAT2, IARS, IARS2
# BRD-A04447196-001-01-8::2.5::MTS004                                          -
# BRD-A04971881-003-01-3::2.65294603::MTS004                 ADRB1, ADRB2, ADRB3
#
#                                             disease.area   indication  \
# column_name
# BRD-A00055058-001-01-0::2.325889319::MTS004            -            -
# BRD-A00842753-001-01-9::2.5::MTS004                    -            -
# BRD-A02232681-001-01-8::2.5::MTS004                    -            -
# BRD-A04447196-001-01-8::2.5::MTS004           cardiology  hypotension
# BRD-A04971881-003-01-3::2.65294603::MTS004             -            -
#
#                                                                                         smiles  \
# column_name
# BRD-A00055058-001-01-0::2.325889319::MTS004             CC(NC(=O)C1CSCN1C(=O)c1ccccc1)c1ccccc1
# BRD-A00842753-001-01-9::2.5::MTS004          COC(=O)C1=COC(OC2OC(CO)C(O)C(O)C2O)\C(=C/C)C1C...
# BRD-A02232681-001-01-8::2.5::MTS004                                           CCC(C)C(N)C(O)=O
# BRD-A04447196-001-01-8::2.5::MTS004                                          CC(N)Cc1cccc(O)c1
# BRD-A04971881-003-01-3::2.65294603::MTS004                      CC(C)(C)NCC(O)COc1cc(Cl)ccc1Cl
#
#                                                 phase
# column_name
# BRD-A00055058-001-01-0::2.325889319::MTS004   Phase 2
# BRD-A00842753-001-01-9::2.5::MTS004           Phase 2
# BRD-A02232681-001-01-8::2.5::MTS004          Launched
# BRD-A04447196-001-01-8::2.5::MTS004          Launched
# BRD-A04971881-003-01-3::2.65294603::MTS004   Launched

# %%
pik3ca_drugs = [x for x in druginfo.index if ('PIK3CA' in druginfo.loc[x,'target'])]
pik3ca_drugs
# Out:
# ['BRD-K24666289-001-04-9::2.499988887::MTS004',
#  'BRD-K02404261-001-16-7::2.5::HTS',
#  'BRD-K07310275-001-02-5::2.5::HTS',
#  'BRD-K07955840-001-02-3::2.5::HTS',
#  'BRD-K07972848-001-02-0::2.5::HTS',
#  'BRD-K12184916-001-15-4::2.5::HTS',
#  'BRD-K23228615-001-02-8::2.5::HTS',
#  'BRD-K27305650-001-16-6::2.5::HTS',
#  'BRD-K28352084-001-02-3::2.5::HTS',
#  'BRD-K29415052-050-04-8::2.5::HTS',
#  'BRD-K30977212-001-02-8::2.5::HTS',
#  'BRD-K42191735-001-05-3::2.5::HTS',
#  'BRD-K43187018-001-03-3::2.52::HTS',
#  'BRD-K44844162-001-01-6::2.5::HTS',
#  'BRD-K49055432-001-04-2::2.5::HTS',
#  'BRD-K49371609-003-03-8::2.5::HTS',
#  'BRD-K52911425-001-09-8::2.5::HTS',
#  'BRD-K54997624-001-06-0::2.5::HTS',
#  'BRD-K56291712-001-01-0::2.5::HTS',
#  'BRD-K58772419-001-07-0::2.5::HTS',
#  'BRD-K59317601-001-05-5::2.5::HTS',
#  'BRD-K60866521-001-07-1::2.5::HTS',
#  'BRD-K63915849-001-03-7::2.5::HTS',
#  'BRD-K64785675-001-04-0::2.5::HTS',
#  'BRD-K67868012-001-07-6::2.5::HTS',
#  'BRD-K81801188-001-02-8::2.5::HTS',
#  'BRD-K93468883-001-02-0::2.5::HTS',
#  'BRD-K95901403-001-04-5::2.5::HTS',
#  'BRD-K98795921-001-01-7::2.5::HTS']

# %%
igf1r_drugs = [x for x in druginfo.index if ('IGF1R' in druginfo.loc[x,'target'])]
igf1r_drugs
# Out:
# ['BRD-K22149900-001-03-9::2.371298578::MTS004',
#  'BRD-K04833372-001-06-2::2.5::HTS',
#  'BRD-K06749501-001-02-1::2.5::HTS',
#  'BRD-K08310154-001-03-8::2.5::HTS',
#  'BRD-K13049116-001-05-7::2.5::HTS',
#  'BRD-K15179513-001-03-4::2.5::HTS',
#  'BRD-K24593301-001-02-3::2.54::HTS',
#  'BRD-K24696047-001-02-3::2.5::HTS',
#  'BRD-K28392481-001-05-1::2.5::HTS',
#  'BRD-K47869605-001-32-0::2.5::HTS',
#  'BRD-K67537649-001-04-5::2.5::HTS',
#  'BRD-K86118762-001-01-8::2.5::HTS']

# %%
akt_drugs = [x for x in druginfo.index if ('AKT' in druginfo.loc[x,'target'])]
akt_drugs
# Out:
# ['BRD-A89082344-001-08-7::2.500026693::MTS004',
#  'BRD-K04710043-001-17-8::2.5::MTS004',
#  'BRD-A31990649-304-02-3::2.5::HTS',
#  'BRD-A37704979-001-10-7::2.5::HTS',
#  'BRD-K06543683-066-02-1::2.5::HTS',
#  'BRD-K12040459-001-06-0::2.5::HTS',
#  'BRD-K13049116-001-05-7::2.5::HTS',
#  'BRD-K18787491-001-08-6::2.5::HTS',
#  'BRD-K19939891-001-05-4::2.5::HTS',
#  'BRD-K25412176-001-01-9::2.5::HTS',
#  'BRD-K27305650-001-16-6::2.5::HTS',
#  'BRD-K38332599-001-01-3::2.5::HTS',
#  'BRD-K50168500-001-07-9::2.5::HTS',
#  'BRD-K54330070-001-15-4::2.5::HTS',
#  'BRD-K59745944-001-02-0::2.5::HTS',
#  'BRD-K62810658-001-12-2::2.5::HTS',
#  'BRD-K68065987-300-09-1::2.5::HTS',
#  'BRD-K71480163-001-01-4::2.5::HTS',
#  'BRD-K78177893-001-02-4::2.5::HTS',
#  'BRD-K79404599-001-09-3::2.5::HTS',
#  'BRD-K80431395-001-07-3::2.49::HTS',
#  'BRD-K80431395-001-09-9::2.5::HTS',
#  'BRD-K91701654-001-03-1::2.38::HTS',
#  'BRD-K97118047-001-03-8::2.5::HTS',
#  'BRD-K99023089-001-03-7::2.5::HTS']

# %%
insr_drugs = [x for x in druginfo.index if ('INSR' in druginfo.loc[x,'target'])]
insr_drugs
# Out:
# ['BRD-K22149900-001-03-9::2.371298578::MTS004',
#  'BRD-K04833372-001-06-2::2.5::HTS',
#  'BRD-K06749501-001-02-1::2.5::HTS',
#  'BRD-K24696047-001-02-3::2.5::HTS',
#  'BRD-K50140147-001-10-1::2.5::HTS',
#  'BRD-K85402309-001-06-6::2.5::HTS',
#  'BRD-K85402309-389-03-2::2.5::HTS',
#  'BRD-K86118762-001-01-8::2.5::HTS']

# %%
druginfo.loc[akt_drugs]
# Out:
#                                                            broad_id  \
# column_name
# BRD-A89082344-001-08-7::2.500026693::MTS004  BRD-A89082344-001-08-7
# BRD-K04710043-001-17-8::2.5::MTS004          BRD-K04710043-001-17-8
# BRD-A31990649-304-02-3::2.5::HTS             BRD-A31990649-304-02-3
# BRD-A37704979-001-10-7::2.5::HTS             BRD-A37704979-001-10-7
# BRD-K06543683-066-02-1::2.5::HTS             BRD-K06543683-066-02-1
# BRD-K12040459-001-06-0::2.5::HTS             BRD-K12040459-001-06-0
# BRD-K13049116-001-05-7::2.5::HTS             BRD-K13049116-001-05-7
# BRD-K18787491-001-08-6::2.5::HTS             BRD-K18787491-001-08-6
# BRD-K19939891-001-05-4::2.5::HTS             BRD-K19939891-001-05-4
# BRD-K25412176-001-01-9::2.5::HTS             BRD-K25412176-001-01-9
# BRD-K27305650-001-16-6::2.5::HTS             BRD-K27305650-001-16-6
# BRD-K38332599-001-01-3::2.5::HTS             BRD-K38332599-001-01-3
# BRD-K50168500-001-07-9::2.5::HTS             BRD-K50168500-001-07-9
# BRD-K54330070-001-15-4::2.5::HTS             BRD-K54330070-001-15-4
# BRD-K59745944-001-02-0::2.5::HTS             BRD-K59745944-001-02-0
# BRD-K62810658-001-12-2::2.5::HTS             BRD-K62810658-001-12-2
# BRD-K68065987-300-09-1::2.5::HTS             BRD-K68065987-300-09-1
# BRD-K71480163-001-01-4::2.5::HTS             BRD-K71480163-001-01-4
# BRD-K78177893-001-02-4::2.5::HTS             BRD-K78177893-001-02-4
# BRD-K79404599-001-09-3::2.5::HTS             BRD-K79404599-001-09-3
# BRD-K80431395-001-07-3::2.49::HTS            BRD-K80431395-001-07-3
# BRD-K80431395-001-09-9::2.5::HTS             BRD-K80431395-001-09-9
# BRD-K91701654-001-03-1::2.38::HTS            BRD-K91701654-001-03-1
# BRD-K97118047-001-03-8::2.5::HTS             BRD-K97118047-001-03-8
# BRD-K99023089-001-03-7::2.5::HTS             BRD-K99023089-001-03-7
#
#                                                                         name  \
# column_name
# BRD-A89082344-001-08-7::2.500026693::MTS004                       perifosine
# BRD-K04710043-001-17-8::2.5::MTS004                hexamethylenebisacetamide
# BRD-A31990649-304-02-3::2.5::HTS                      adenosine-triphosphate
# BRD-A37704979-001-10-7::2.5::HTS                                   SB-203580
# BRD-K06543683-066-02-1::2.5::HTS                      bisindolylmaleimide-ix
# BRD-K12040459-001-06-0::2.5::HTS                                      AT7867
# BRD-K13049116-001-05-7::2.5::HTS                                  BMS-754807
# BRD-K18787491-001-08-6::2.5::HTS                                      U-0126
# BRD-K19939891-001-05-4::2.5::HTS                                       TIC10
# BRD-K25412176-001-01-9::2.5::HTS                                  GSK2110183
# BRD-K27305650-001-16-6::2.5::HTS                                    LY294002
# BRD-K38332599-001-01-3::2.5::HTS                                  uprosertib
# BRD-K50168500-001-07-9::2.5::HTS                                  canertinib
# BRD-K54330070-001-15-4::2.5::HTS                                   SB-202190
# BRD-K59745944-001-02-0::2.5::HTS                                     PHT-427
# BRD-K62810658-001-12-2::2.5::HTS                                    PD-98059
# BRD-K68065987-300-09-1::2.5::HTS                                     MK-2206
# BRD-K71480163-001-01-4::2.5::HTS                                    GDC-0068
# BRD-K78177893-001-02-4::2.5::HTS                                    A-674563
# BRD-K79404599-001-09-3::2.5::HTS                                 enzastaurin
# BRD-K80431395-001-07-3::2.49::HTS                                triciribine
# BRD-K80431395-001-09-9::2.5::HTS                                 triciribine
# BRD-K91701654-001-03-1::2.38::HTS                                     U-0126
# BRD-K97118047-001-03-8::2.5::HTS             4,5,6,7-tetrabromobenzotriazole
# BRD-K99023089-001-03-7::2.5::HTS                                     AZD5363
#
#                                                  dose screen_id  \
# column_name
# BRD-A89082344-001-08-7::2.500026693::MTS004  2.500027    MTS004
# BRD-K04710043-001-17-8::2.5::MTS004          2.500000    MTS004
# BRD-A31990649-304-02-3::2.5::HTS             2.500000       HTS
# BRD-A37704979-001-10-7::2.5::HTS             2.500000       HTS
# BRD-K06543683-066-02-1::2.5::HTS             2.500000       HTS
# BRD-K12040459-001-06-0::2.5::HTS             2.500000       HTS
# BRD-K13049116-001-05-7::2.5::HTS             2.500000       HTS
# BRD-K18787491-001-08-6::2.5::HTS             2.500000       HTS
# BRD-K19939891-001-05-4::2.5::HTS             2.500000       HTS
# BRD-K25412176-001-01-9::2.5::HTS             2.500000       HTS
# BRD-K27305650-001-16-6::2.5::HTS             2.500000       HTS
# BRD-K38332599-001-01-3::2.5::HTS             2.500000       HTS
# BRD-K50168500-001-07-9::2.5::HTS             2.500000       HTS
# BRD-K54330070-001-15-4::2.5::HTS             2.500000       HTS
# BRD-K59745944-001-02-0::2.5::HTS             2.500000       HTS
# BRD-K62810658-001-12-2::2.5::HTS             2.500000       HTS
# BRD-K68065987-300-09-1::2.5::HTS             2.500000       HTS
# BRD-K71480163-001-01-4::2.5::HTS             2.500000       HTS
# BRD-K78177893-001-02-4::2.5::HTS             2.500000       HTS
# BRD-K79404599-001-09-3::2.5::HTS             2.500000       HTS
# BRD-K80431395-001-07-3::2.49::HTS            2.490000       HTS
# BRD-K80431395-001-09-9::2.5::HTS             2.500000       HTS
# BRD-K91701654-001-03-1::2.38::HTS            2.380000       HTS
# BRD-K97118047-001-03-8::2.5::HTS             2.500000       HTS
# BRD-K99023089-001-03-7::2.5::HTS             2.500000       HTS
#
#                                                                                            moa  \
# column_name
# BRD-A89082344-001-08-7::2.500026693::MTS004                                      AKT inhibitor
# BRD-K04710043-001-17-8::2.5::MTS004          AKT inhibitor, differentiation inducer, NFKB p...
# BRD-A31990649-304-02-3::2.5::HTS                                    adenosine receptor agonist
# BRD-A37704979-001-10-7::2.5::HTS                                            p38 MAPK inhibitor
# BRD-K06543683-066-02-1::2.5::HTS                                                 PKC inhibitor
# BRD-K12040459-001-06-0::2.5::HTS                                                 AKT inhibitor
# BRD-K13049116-001-05-7::2.5::HTS                                               IGF-1 inhibitor
# BRD-K18787491-001-08-6::2.5::HTS                                                 MEK inhibitor
# BRD-K19939891-001-05-4::2.5::HTS                                AKT inhibitor, TRAIL modulator
# BRD-K25412176-001-01-9::2.5::HTS                                                 AKT inhibitor
# BRD-K27305650-001-16-6::2.5::HTS             mTOR inhibitor, PI3K inhibitor, DNA dependent ...
# BRD-K38332599-001-01-3::2.5::HTS                                                 AKT inhibitor
# BRD-K50168500-001-07-9::2.5::HTS                                                EGFR inhibitor
# BRD-K54330070-001-15-4::2.5::HTS                                            p38 MAPK inhibitor
# BRD-K59745944-001-02-0::2.5::HTS               AKT inhibitor, pyruvate dehydrogenase inhibitor
# BRD-K62810658-001-12-2::2.5::HTS                                                 MEK inhibitor
# BRD-K68065987-300-09-1::2.5::HTS                                                 AKT inhibitor
# BRD-K71480163-001-01-4::2.5::HTS                                                 AKT inhibitor
# BRD-K78177893-001-02-4::2.5::HTS                                                 AKT inhibitor
# BRD-K79404599-001-09-3::2.5::HTS                                                 PKC inhibitor
# BRD-K80431395-001-07-3::2.49::HTS                                                AKT inhibitor
# BRD-K80431395-001-09-9::2.5::HTS                                                 AKT inhibitor
# BRD-K91701654-001-03-1::2.38::HTS                                                MEK inhibitor
# BRD-K97118047-001-03-8::2.5::HTS                                       casein kinase inhibitor
# BRD-K99023089-001-03-7::2.5::HTS                                                 AKT inhibitor
#
#                                                                                         target  \
# column_name
# BRD-A89082344-001-08-7::2.500026693::MTS004                                               AKT1
# BRD-K04710043-001-17-8::2.5::MTS004                                                       AKT1
# BRD-A31990649-304-02-3::2.5::HTS             ABCA1, ABCB1, ABCB11, ABCC2, ABCC8, ABCC9, ABC...
# BRD-A37704979-001-10-7::2.5::HTS             AKT1, ALOX5, CHEK1, CYP2D6, CYP3A4, GAK, GSK3B...
# BRD-K06543683-066-02-1::2.5::HTS             AKT1, GSK3B, LCK, MAPK1, MAPK11, MAPK12, MAPK1...
# BRD-K12040459-001-06-0::2.5::HTS                                     AKT2, GSK3B, PKIA, PRKACA
# BRD-K13049116-001-05-7::2.5::HTS                                                   AKT1, IGF1R
# BRD-K18787491-001-08-6::2.5::HTS             AKT1, CHEK1, GSK3B, LCK, MAP2K1, MAP2K2, MAP2K...
# BRD-K19939891-001-05-4::2.5::HTS                                                   AKT1, MAPK1
# BRD-K25412176-001-01-9::2.5::HTS                                              AKT1, AKT2, AKT3
# BRD-K27305650-001-16-6::2.5::HTS             AKT1, CHEK1, GSK3B, LCK, MAPK1, MAPK11, MAPK12...
# BRD-K38332599-001-01-3::2.5::HTS                                              AKT1, AKT2, AKT3
# BRD-K50168500-001-07-9::2.5::HTS                                      AKT1, EGFR, ERBB2, ERBB4
# BRD-K54330070-001-15-4::2.5::HTS             AKT1, ALOX5, CHEK1, GSK3B, LCK, MAPK1, MAPK11,...
# BRD-K59745944-001-02-0::2.5::HTS                                                   AKT2, PDPK1
# BRD-K62810658-001-12-2::2.5::HTS             AKT1, CHEK1, GSK3B, LCK, MAP2K1, MAPK1, MAPK11...
# BRD-K68065987-300-09-1::2.5::HTS                                              AKT1, AKT2, AKT3
# BRD-K71480163-001-01-4::2.5::HTS                                       AKT1, AKT2, AKT3, PRKG1
# BRD-K78177893-001-02-4::2.5::HTS                                            AKT1, PKIA, PRKACA
# BRD-K79404599-001-09-3::2.5::HTS                       AKT1, GSK3B, PRKCA, PRKCB, PRKCD, PRKCG
# BRD-K80431395-001-07-3::2.49::HTS                                             AKT1, AKT2, AKT3
# BRD-K80431395-001-09-9::2.5::HTS                                              AKT1, AKT2, AKT3
# BRD-K91701654-001-03-1::2.38::HTS            AKT1, CHEK1, GSK3B, LCK, MAP2K1, MAP2K2, MAP2K...
# BRD-K97118047-001-03-8::2.5::HTS             AKT1, CHEK1, CSNK2A1, GSK3B, LCK, MAP2K1, MAPK...
# BRD-K99023089-001-03-7::2.5::HTS                                              AKT1, AKT2, AKT3
#
#                                             disease.area indication  \
# column_name
# BRD-A89082344-001-08-7::2.500026693::MTS004            -          -
# BRD-K04710043-001-17-8::2.5::MTS004                    -          -
# BRD-A31990649-304-02-3::2.5::HTS                       -          -
# BRD-A37704979-001-10-7::2.5::HTS                       -          -
# BRD-K06543683-066-02-1::2.5::HTS                       -          -
# BRD-K12040459-001-06-0::2.5::HTS                       -          -
# BRD-K13049116-001-05-7::2.5::HTS                       -          -
# BRD-K18787491-001-08-6::2.5::HTS                       -          -
# BRD-K19939891-001-05-4::2.5::HTS                       -          -
# BRD-K25412176-001-01-9::2.5::HTS                       -          -
# BRD-K27305650-001-16-6::2.5::HTS                       -          -
# BRD-K38332599-001-01-3::2.5::HTS                       -          -
# BRD-K50168500-001-07-9::2.5::HTS                       -          -
# BRD-K54330070-001-15-4::2.5::HTS                       -          -
# BRD-K59745944-001-02-0::2.5::HTS                       -          -
# BRD-K62810658-001-12-2::2.5::HTS                       -          -
# BRD-K68065987-300-09-1::2.5::HTS                       -          -
# BRD-K71480163-001-01-4::2.5::HTS                       -          -
# BRD-K78177893-001-02-4::2.5::HTS                       -          -
# BRD-K79404599-001-09-3::2.5::HTS                       -          -
# BRD-K80431395-001-07-3::2.49::HTS                      -          -
# BRD-K80431395-001-09-9::2.5::HTS                       -          -
# BRD-K91701654-001-03-1::2.38::HTS                      -          -
# BRD-K97118047-001-03-8::2.5::HTS                       -          -
# BRD-K99023089-001-03-7::2.5::HTS                       -          -
#
#                                                                                         smiles  \
# column_name
# BRD-A89082344-001-08-7::2.500026693::MTS004  CCCCCCCCCCCCCCCCCCOP(O)(=O)OC1CC[N+](C)(C)CC1,...
# BRD-K04710043-001-17-8::2.5::MTS004                                       CC(=O)NCCCCCCNC(C)=O
# BRD-A31990649-304-02-3::2.5::HTS             Nc1ncnc2n(cnc12)[C@@H]1O[C@H](COP(O)(=O)OP(O)(...
# BRD-A37704979-001-10-7::2.5::HTS             CS(=O)c1ccc(cc1)-c1nc(c([nH]1)-c1ccncc1)-c1ccc...
# BRD-K06543683-066-02-1::2.5::HTS             Cn1cc(C2=C(C(=O)NC2=O)c2cn(CCCSC(N)=N)c3ccccc2...
# BRD-K12040459-001-06-0::2.5::HTS             Clc1ccc(cc1)C1(CCNCC1)c1ccc(cc1)-c1cn[nH]c1, C...
# BRD-K13049116-001-05-7::2.5::HTS             C[C@]1(CCCN1c1nc(Nc2cc(n[nH]2)C2CC2)c2cccn2n1)...
# BRD-K18787491-001-08-6::2.5::HTS             N\C(Sc1ccccc1N)=C(C#N)/C(C#N)=C(/N)Sc1ccccc1N,...
# BRD-K19939891-001-05-4::2.5::HTS             Cc1ccccc1CN1CC2=C(CCN(Cc3ccccc3)C2=O)N2CCN=C12...
# BRD-K25412176-001-01-9::2.5::HTS             Cn1ncc(Cl)c1-c1cc(sc1Cl)C(=O)N[C@H](CN)Cc1cccc...
# BRD-K27305650-001-16-6::2.5::HTS             O=c1cc(oc2c(cccc12)-c1ccccc1)N1CCOCC1, O=c1cc(...
# BRD-K38332599-001-01-3::2.5::HTS             Cn1ncc(Cl)c1-c1cc(oc1Cl)C(=O)N[C@H](CN)Cc1ccc(...
# BRD-K50168500-001-07-9::2.5::HTS             Fc1ccc(Nc2ncnc3cc(OCCCN4CCOCC4)c(NC(=O)C=C)cc2...
# BRD-K54330070-001-15-4::2.5::HTS             Oc1ccc(cc1)-c1nc(c([nH]1)-c1ccncc1)-c1ccc(F)cc...
# BRD-K59745944-001-02-0::2.5::HTS             CCCCCCCCCCCCc1ccc(cc1)S(=O)(=O)Nc1nncs1, CCCCC...
# BRD-K62810658-001-12-2::2.5::HTS             COc1cccc(-c2cc(=O)c3ccccc3o2)c1N, COc1cccc(-c2...
# BRD-K68065987-300-09-1::2.5::HTS             NC1(CCC1)c1ccc(cc1)-c1nc2ccn3c(n[nH]c3=O)c2cc1...
# BRD-K71480163-001-01-4::2.5::HTS             CC(C)NC[C@@H](C(=O)N1CCN(CC1)c1ncnc2[C@@H](O)C...
# BRD-K78177893-001-02-4::2.5::HTS             Cc1n[nH]c2ccc(cc12)-c1cncc(OC[C@@H](N)Cc2ccccc...
# BRD-K79404599-001-09-3::2.5::HTS             Cn1cc(C2=C(C(=O)NC2=O)c2cn(C3CCN(Cc4ccccn4)CC3...
# BRD-K80431395-001-07-3::2.49::HTS            Cn1nc(N)c2cn([C@@H]3O[C@H](CO)[C@@H](O)[C@H]3O...
# BRD-K80431395-001-09-9::2.5::HTS             Cn1nc(N)c2cn([C@@H]3O[C@H](CO)[C@@H](O)[C@H]3O...
# BRD-K91701654-001-03-1::2.38::HTS            N\C(Sc1ccccc1N)=C(C#N)/C(C#N)=C(/N)Sc1ccccc1N,...
# BRD-K97118047-001-03-8::2.5::HTS             Brc1c(Br)c(Br)c2[nH]nnc2c1Br, Brc1c(Br)c(Br)c2...
# BRD-K99023089-001-03-7::2.5::HTS             NC1(CCN(CC1)c1ncnc2[nH]ccc12)C(=O)N[C@@H](CCO)...
#
#                                                        phase
# column_name
# BRD-A89082344-001-08-7::2.500026693::MTS004          Phase 3
# BRD-K04710043-001-17-8::2.5::MTS004                  Phase 2
# BRD-A31990649-304-02-3::2.5::HTS                     Phase 2
# BRD-A37704979-001-10-7::2.5::HTS                 Preclinical
# BRD-K06543683-066-02-1::2.5::HTS                 Preclinical
# BRD-K12040459-001-06-0::2.5::HTS                 Preclinical
# BRD-K13049116-001-05-7::2.5::HTS                     Phase 2
# BRD-K18787491-001-08-6::2.5::HTS                 Preclinical
# BRD-K19939891-001-05-4::2.5::HTS                     Phase 2
# BRD-K25412176-001-01-9::2.5::HTS                     Phase 2
# BRD-K27305650-001-16-6::2.5::HTS                 Preclinical
# BRD-K38332599-001-01-3::2.5::HTS                     Phase 2
# BRD-K50168500-001-07-9::2.5::HTS                     Phase 3
# BRD-K54330070-001-15-4::2.5::HTS                 Preclinical
# BRD-K59745944-001-02-0::2.5::HTS                 Preclinical
# BRD-K62810658-001-12-2::2.5::HTS                 Preclinical
# BRD-K68065987-300-09-1::2.5::HTS                     Phase 2
# BRD-K71480163-001-01-4::2.5::HTS                     Phase 2
# BRD-K78177893-001-02-4::2.5::HTS                 Preclinical
# BRD-K79404599-001-09-3::2.5::HTS                     Phase 3
# BRD-K80431395-001-07-3::2.49::HTS            Phase 1/Phase 2
# BRD-K80431395-001-09-9::2.5::HTS             Phase 1/Phase 2
# BRD-K91701654-001-03-1::2.38::HTS                Preclinical
# BRD-K97118047-001-03-8::2.5::HTS                 Preclinical
# BRD-K99023089-001-03-7::2.5::HTS                     Phase 2

# %%
qbf.PIK3CA.corr( drugsens[ akt_drugs[0] ] )
# Out:
# 0.075882711708683

# %%
#
# PIK3CA GOF muts vs. other
#
pik3ca_gof = feats.index[ where( feats.PIK3CA_GOF==True)[0] ]
pik3ca_wt = feats.index[ where( feats.PIK3CA_GOF==False)[0] ]
print( len(pik3ca_gof), len(pik3ca_wt))
# Out:
# 54 354

# %%
#
# pik3ca bf vs pik3ca inhibitors
# 
pcc_pik3i = pd.DataFrame( columns=['drug','PCC','PIK3CA_GOF'], dtype=float)

idx = 0
for pik3i in pik3ca_drugs:
    pcc_pik3 = qbf.loc[pik3ca_gof].PIK3CA.corr( drugsens[ pik3i ] )
    pcc_wt = qbf.loc[pik3ca_wt].PIK3CA.corr( drugsens[ pik3i ] )
    pcc_pik3i.loc[idx] = [pik3i, pcc_wt, 0]
    idx = idx + 1
    pcc_pik3i.loc[idx] = [pik3i, pcc_pik3, 1]
    idx = idx + 1

    
my_order = [False,True]
my_palette = {True: sns.color_palette("tab10")[1], False: sns.color_palette("tab10")[0]}

figure( figsize(3,4))
sns.stripplot( x='PIK3CA_GOF', y='PCC', data=pcc_pik3i, s=4, order=my_order, palette=my_palette)
ylabel('PCC, BF vs PIK3CA inhibitor')
ylim(-0.6,0.4)
# Out:
# (-0.6, 0.4)

# %%
stats.ttest_rel( pcc_pik3i[ pcc_pik3i.PIK3CA_GOF==0].PCC, pcc_pik3i[ pcc_pik3i.PIK3CA_GOF==1].PCC)
# Out:
# Ttest_relResult(statistic=2.729181111676294, pvalue=0.010848705825404363)

# %%
#
# pik3ca bf vs igf1r inhibitors
# 
pcc_igf1ri = pd.DataFrame( columns=['drug','PCC','PIK3CA_GOF'], dtype=float)


idx = 0
for drug in igf1r_drugs:
    pcc_igf1ri.loc[idx] = [drug, qbf.loc[pik3ca_wt].PIK3CA.corr( drugsens[ drug ] ) , 0]
    idx = idx + 1
    pcc_igf1ri.loc[idx] = [drug, qbf.loc[pik3ca_gof].PIK3CA.corr( drugsens[ drug ] ) , 1]
    idx = idx + 1

    
my_order = [False,True]
my_palette = {True: sns.color_palette("tab10")[1], False: sns.color_palette("tab10")[0]}

figure( figsize(3,4))
sns.stripplot( x='PIK3CA_GOF', y='PCC', data=pcc_igf1ri, s=4, order=my_order, palette=my_palette)
ylabel('PCC, BF vs IGF1R inhibitor')
ylim(-0.6,0.4)
# Out:
# (-0.6, 0.4)

# %%
stats.ttest_rel( pcc_igf1ri[ pcc_igf1ri.PIK3CA_GOF==0].PCC, pcc_igf1ri[ pcc_igf1ri.PIK3CA_GOF==1].PCC)
# Out:
# Ttest_relResult(statistic=-0.8169748059557724, pvalue=0.43128148693279955)

# %%
#
# pik3ca bf vs akti inhibitors
# 
pcc_akt1 = pd.DataFrame( columns=['drug','PCC','PIK3CA_GOF'], dtype=float)


idx = 0
for drug in akt_drugs:
    pcc_akt1.loc[idx] = [drug, qbf.loc[pik3ca_wt].PIK3CA.corr( drugsens[ drug ] ) , 0]
    idx = idx + 1
    pcc_akt1.loc[idx] = [drug, qbf.loc[pik3ca_gof].PIK3CA.corr( drugsens[ drug ] ) , 1]
    idx = idx + 1

    
my_order = [False,True]
my_palette = {True: sns.color_palette("tab10")[1], False: sns.color_palette("tab10")[0]}

figure( figsize(3,4))
sns.stripplot( x='PIK3CA_GOF', y='PCC', data=pcc_akt1, s=4, order=my_order, palette=my_palette)
ylabel('PCC, BF vs AKT inhibitor')
ylim(-0.6,0.4)
# Out:
# (-0.6, 0.4)

# %%
stats.ttest_rel( pcc_akt1[ pcc_akt1.PIK3CA_GOF==0].PCC, pcc_akt1[ pcc_akt1.PIK3CA_GOF==1].PCC)
# Out:
# Ttest_relResult(statistic=2.4950512080836034, pvalue=0.019871801355034423)

# %%
#
# pik3ca bf vs insr inhibitors
# 
pcc_insr = pd.DataFrame( columns=['drug','PCC','PIK3CA_GOF'], dtype=float)


idx = 0
for drug in insr_drugs:
    pcc_insr.loc[idx] = [drug, qbf.loc[pik3ca_wt].PIK3CA.corr( drugsens[ drug ] ) , 0]
    idx = idx + 1
    pcc_insr.loc[idx] = [drug, qbf.loc[pik3ca_gof].PIK3CA.corr( drugsens[ drug ] ) , 1]
    idx = idx + 1

    
my_order = [False,True]
my_palette = {True: sns.color_palette("tab10")[1], False: sns.color_palette("tab10")[0]}

figure( figsize(3,4))
sns.stripplot( x='PIK3CA_GOF', y='PCC', data=pcc_insr, s=4, order=my_order, palette=my_palette)
#ylabel('PCC, BF vs INSR inhibitor')
ylim(-0.6,0.4)
# Out:
# (-0.6, 0.4)

# %%
pcc_pik3i.nsmallest( 10, 'PCC')
# Out:
#                                 drug       PCC  PIK3CA_GOF
# 27  BRD-K44844162-001-01-6::2.5::HTS -0.499794         1.0
# 17  BRD-K28352084-001-02-3::2.5::HTS -0.475397         1.0
# 35  BRD-K54997624-001-06-0::2.5::HTS -0.425069         1.0
# 49  BRD-K67868012-001-07-6::2.5::HTS -0.415535         1.0
# 29  BRD-K49055432-001-04-2::2.5::HTS -0.395769         1.0
# 32  BRD-K52911425-001-09-8::2.5::HTS -0.380211         0.0
# 26  BRD-K44844162-001-01-6::2.5::HTS -0.364580         0.0
# 34  BRD-K54997624-001-06-0::2.5::HTS -0.356799         0.0
# 33  BRD-K52911425-001-09-8::2.5::HTS -0.343021         1.0
# 28  BRD-K49055432-001-04-2::2.5::HTS -0.319844         0.0

# %%
druginfo.loc[ pcc_pik3i[ pcc_pik3i.PIK3CA_GOF==1 ].nsmallest( 3, 'PCC').drug  ]
# Out:
#                                                 broad_id       name  dose  \
# column_name
# BRD-K44844162-001-01-6::2.5::HTS  BRD-K44844162-001-01-6  taselisib   2.5
# BRD-K28352084-001-02-3::2.5::HTS  BRD-K28352084-001-02-3  CH5132799   2.5
# BRD-K54997624-001-06-0::2.5::HTS  BRD-K54997624-001-06-0  alpelisib   2.5
#
#                                  screen_id             moa  \
# column_name
# BRD-K44844162-001-01-6::2.5::HTS       HTS  PI3K inhibitor
# BRD-K28352084-001-02-3::2.5::HTS       HTS  PI3K inhibitor
# BRD-K54997624-001-06-0::2.5::HTS       HTS  PI3K inhibitor
#
#                                                                 target  \
# column_name
# BRD-K44844162-001-01-6::2.5::HTS                                PIK3CA
# BRD-K28352084-001-02-3::2.5::HTS  MTOR, PIK3CA, PIK3CB, PIK3CD, PIK3CG
# BRD-K54997624-001-06-0::2.5::HTS        PIK3CA, PIK3CB, PIK3CD, PIK3CG
#
#                                  disease.area indication  \
# column_name
# BRD-K44844162-001-01-6::2.5::HTS            -          -
# BRD-K28352084-001-02-3::2.5::HTS            -          -
# BRD-K54997624-001-06-0::2.5::HTS            -          -
#
#                                                                              smiles  \
# column_name
# BRD-K44844162-001-01-6::2.5::HTS  CC(C)n1nc(C)nc1-c1cn2CCOc3cc(ccc3-c2n1)-c1cnn(...
# BRD-K28352084-001-02-3::2.5::HTS  CS(=O)(=O)N1CCc2c1nc(nc2-c1cnc(N)nc1)N1CCOCC1,...
# BRD-K54997624-001-06-0::2.5::HTS  Cc1nc(NC(=O)N2CCC[C@H]2C(N)=O)sc1-c1ccnc(c1)C(...
#
#                                     phase
# column_name
# BRD-K44844162-001-01-6::2.5::HTS  Phase 3
# BRD-K28352084-001-02-3::2.5::HTS  Phase 1
# BRD-K54997624-001-06-0::2.5::HTS  Phase 3

# %%
pcc_pik3i[ pcc_pik3i.PIK3CA_GOF==0 ].nsmallest( 3, 'PCC')
# Out:
#                                 drug       PCC  PIK3CA_GOF
# 32  BRD-K52911425-001-09-8::2.5::HTS -0.380211         0.0
# 26  BRD-K44844162-001-01-6::2.5::HTS -0.364580         0.0
# 34  BRD-K54997624-001-06-0::2.5::HTS -0.356799         0.0

# %%
druginfo.loc[ pcc_pik3i[ pcc_pik3i.PIK3CA_GOF==0 ].nsmallest( 3, 'PCC').drug  ]
# Out:
#                                                 broad_id       name  dose  \
# column_name
# BRD-K52911425-001-09-8::2.5::HTS  BRD-K52911425-001-09-8   GDC-0941   2.5
# BRD-K44844162-001-01-6::2.5::HTS  BRD-K44844162-001-01-6  taselisib   2.5
# BRD-K54997624-001-06-0::2.5::HTS  BRD-K54997624-001-06-0  alpelisib   2.5
#
#                                  screen_id             moa  \
# column_name
# BRD-K52911425-001-09-8::2.5::HTS       HTS  PI3K inhibitor
# BRD-K44844162-001-01-6::2.5::HTS       HTS  PI3K inhibitor
# BRD-K54997624-001-06-0::2.5::HTS       HTS  PI3K inhibitor
#
#                                                           target disease.area  \
# column_name
# BRD-K52911425-001-09-8::2.5::HTS  PIK3CA, PIK3CB, PIK3CD, PIK3CG            -
# BRD-K44844162-001-01-6::2.5::HTS                          PIK3CA            -
# BRD-K54997624-001-06-0::2.5::HTS  PIK3CA, PIK3CB, PIK3CD, PIK3CG            -
#
#                                  indication  \
# column_name
# BRD-K52911425-001-09-8::2.5::HTS          -
# BRD-K44844162-001-01-6::2.5::HTS          -
# BRD-K54997624-001-06-0::2.5::HTS          -
#
#                                                                              smiles  \
# column_name
# BRD-K52911425-001-09-8::2.5::HTS  CS(=O)(=O)N1CCN(Cc2cc3nc(nc(N4CCOCC4)c3s2)-c2c...
# BRD-K44844162-001-01-6::2.5::HTS  CC(C)n1nc(C)nc1-c1cn2CCOc3cc(ccc3-c2n1)-c1cnn(...
# BRD-K54997624-001-06-0::2.5::HTS  Cc1nc(NC(=O)N2CCC[C@H]2C(N)=O)sc1-c1ccnc(c1)C(...
#
#                                     phase
# column_name
# BRD-K52911425-001-09-8::2.5::HTS  Phase 2
# BRD-K44844162-001-01-6::2.5::HTS  Phase 3
# BRD-K54997624-001-06-0::2.5::HTS  Phase 3

# %%
pcc_akt1.nsmallest( 10, 'PCC')
# Out:
#                                  drug       PCC  PIK3CA_GOF
# 33   BRD-K68065987-300-09-1::2.5::HTS -0.462533         1.0
# 25   BRD-K50168500-001-07-9::2.5::HTS -0.370174         1.0
# 49   BRD-K99023089-001-03-7::2.5::HTS -0.345526         1.0
# 35   BRD-K71480163-001-01-4::2.5::HTS -0.315912         1.0
# 29   BRD-K59745944-001-02-0::2.5::HTS -0.309282         1.0
# 43   BRD-K80431395-001-09-9::2.5::HTS -0.296758         1.0
# 19   BRD-K25412176-001-01-9::2.5::HTS -0.279112         1.0
# 41  BRD-K80431395-001-07-3::2.49::HTS -0.249759         1.0
# 37   BRD-K78177893-001-02-4::2.5::HTS -0.215652         1.0
# 24   BRD-K50168500-001-07-9::2.5::HTS -0.210155         0.0

# %%
druginfo.loc['BRD-K68065987-300-09-1::2.5::HTS']
# Out:
# broad_id                                   BRD-K68065987-300-09-1
# name                                                      MK-2206
# dose                                                          2.5
# screen_id                                                     HTS
# moa                                                 AKT inhibitor
# target                                           AKT1, AKT2, AKT3
# disease.area                                                    -
# indication                                                      -
# smiles          NC1(CCC1)c1ccc(cc1)-c1nc2ccn3c(n[nH]c3=O)c2cc1...
# phase                                                     Phase 2
# Name: BRD-K68065987-300-09-1::2.5::HTS, dtype: object
